# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('Jobs.csv')
df.head(5)
# Out:
#                                        job_title  \
# 0                      Data Analyst-SQL, Tableau
# 1             Market Research & Insights Analyst
# 2                    Business Systems Analyst `1
# 3            Senior VAT and Indirect Tax Analyst
# 4  Senior HRIS Analyst (Timekeeping and Payroll)
#
#                          company              job_location  \
# 0              Zortech Solutions         Mountain View, CA
# 1  Indiana University Foundation           Bloomington, IN
# 2                   Cook Medical           Bloomington, IN
# 3                           Epic           Bloomington, IN
# 4            Nordson Corporation  Greater Bloomington Area
#
#                                             job_link  first_seen  search_city  \
# 0    https://www.linkedin.com/jobs/data-analyst-jobs  2023-12-20  Bloomington
# 1  https://www.linkedin.com/jobs/view/market-rese...  2023-12-20  Bloomington
# 2  https://www.linkedin.com/jobs/view/business-sy...  2023-12-20  Bloomington
# 3  https://www.linkedin.com/jobs/view/senior-vat-...  2023-12-20  Bloomington
# 4  https://www.linkedin.com/jobs/view/senior-hris...  2023-12-20  Bloomington
#
#   search_country   job level job_type  \
# 0  United States   Associate   Onsite
# 1  United States  Mid senior   Onsite
# 2  United States  Mid senior   Onsite
# 3  United States  Mid senior   Onsite
# 4  United States  Mid senior   Remote
#
#                                          job_summary  \
# 0                                      Not Available
# 1  Company Description\nAre you a high-performer ...
# 2  Overview\nThe Business Systems Analyst 1 perfo...
# 3  We're looking for an experienced tax professio...
# 4  Collaboration drives Nordson’s success as a ma...
#
#                                           job_skills  Year  Month  Day  \
# 0                                      Not Specified  2023     12   20
# 1  Data analysis, Market research, Survey develop...  2023     12   20
# 2  Business Analysis, Technical Writing, Software...  2023     12   20
# 3  Accounting, Finance, VAT/GST tax regimes, US a...  2023     12   20
# 4  Workday HCM, UKG Dimensions, Ceridian Dayforce...  2023     12   20
#
#   Month_Name  Number_of_Skills  Remote_Flag
# 0   December                 1            0
# 1   December                23            0
# 2   December                12            0
# 3   December                36            0
# 4   December                27            1

# %%
df.tail(5)
# Out:
#                             job_title                   company  \
# 11379            Quantitative Analyst   NextEra Energy Services
# 11380            Quantitative Analyst            Energy Jobline
# 11381            Quantitative Analyst  NextEra Energy Resources
# 11382            Quantitative Analyst      NextEra Energy, Inc.
# 11383  Associate Quantitative Analyst            Energy Jobline
#
#                job_location  \
# 11379        Juno Beach, FL
# 11380  North Palm Beach, FL
# 11381        Juno Beach, FL
# 11382        Juno Beach, FL
# 11383  North Palm Beach, FL
#
#                                                 job_link  first_seen  \
# 11379  https://www.linkedin.com/jobs/view/quantitativ...  2023-12-20
# 11380  https://www.linkedin.com/jobs/view/quantitativ...  2023-12-20
# 11381  https://www.linkedin.com/jobs/view/quantitativ...  2023-12-20
# 11382  https://www.linkedin.com/jobs/view/quantitativ...  2023-12-20
# 11383  https://www.linkedin.com/jobs/view/associate-q...  2023-12-20
#
#         search_city search_country   job level job_type  \
# 11379  Palm Springs  United States  Mid senior   Onsite
# 11380  Palm Springs  United States  Mid senior   Onsite
# 11381  Palm Springs  United States  Mid senior   Onsite
# 11382  Palm Springs  United States  Mid senior   Onsite
# 11383  Palm Springs  United States  Mid senior   Hybrid
#
#                                              job_summary  \
# 11379  Requisition ID: 76277\nFlorida Power & Light C...
# 11380  Requisition ID: 76277\nFlorida Power & Light C...
# 11381  Requisition ID:\n76277\nFlorida Power & Light ...
# 11382  Requisition ID:\n76277\nFlorida Power & Light ...
# 11383  Requisition ID: 77422\nNextEra Energy Marketin...
#
#                                               job_skills  Year  Month  Day  \
# 11379  Quantitative analysis, Statistics, Mathematics...  2023     12   20
# 11380  Quantitative analysis, GenTrader, Excel, Pytho...  2023     12   20
# 11381  Production Cost Models, Power Trading, Data Co...  2023     12   20
# 11382  GenTrader, Production Cost Models, Data collec...  2023     12   20
# 11383  Mathematical models, Energy derivatives, Spot/...  2023     12   20
#
#       Month_Name  Number_of_Skills  Remote_Flag
# 11379   December                23            0
# 11380   December                16            0
# 11381   December                15            0
# 11382   December                15            0
# 11383   December                16            2

# %%
df.columns
# Out:
# Index(['job_title', 'company', 'job_location', 'job_link', 'first_seen',
#        'search_city', 'search_country', 'job level', 'job_type', 'job_summary',
#        'job_skills', 'Year', 'Month', 'Day', 'Month_Name', 'Number_of_Skills',
#        'Remote_Flag'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11384 entries, 0 to 11383
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         11384 non-null  object
#  1   company           11384 non-null  object
#  2   job_location      11384 non-null  object
#  3   job_link          11384 non-null  object
#  4   first_seen        11384 non-null  object
#  5   search_city       11384 non-null  object
#  6   search_country    11384 non-null  object
#  7   job level         11384 non-null  object
#  8   job_type          11384 non-null  object
#  9   job_summary       11384 non-null  object
#  10  job_skills        11384 non-null  object
#  11  Year              11384 non-null  int64
#  12  Month             11384 non-null  int64
#  13  Day               11384 non-null  int64
#  14  Month_Name        11384 non-null  object
#  15  Number_of_Skills  11384 non-null  int64
#  16  Remote_Flag       11384 non-null  int64
# dtypes: int64(5), object(12)
# memory usage: 1.5+ MB

# %%
df.dtypes
# Out:
# job_title           object
# company             object
# job_location        object
# job_link            object
# first_seen          object
# search_city         object
# search_country      object
# job level           object
# job_type            object
# job_summary         object
# job_skills          object
# Year                 int64
# Month                int64
# Day                  int64
# Month_Name          object
# Number_of_Skills     int64
# Remote_Flag          int64
# dtype: object

# %%
df.describe()
# Out:
#           Year    Month      Day  Number_of_Skills   Remote_Flag
# count  11384.0  11384.0  11384.0      11384.000000  11384.000000
# mean    2023.0     12.0     20.0         17.787333      0.827038
# std        0.0      0.0      0.0          9.256723      0.906333
# min     2023.0     12.0     20.0          1.000000      0.000000
# 25%     2023.0     12.0     20.0         12.000000      0.000000
# 50%     2023.0     12.0     20.0         16.000000      0.000000
# 75%     2023.0     12.0     20.0         22.000000      2.000000
# max     2023.0     12.0     20.0        135.000000      2.000000

# %%
df.shape
# Out:
# (11384, 17)

# %%
df.nunique().reset_index(name='count')
# Out:
#                index  count
# 0          job_title   6088
# 1            company   4751
# 2       job_location   2216
# 3           job_link  11384
# 4         first_seen      1
# 5        search_city    680
# 6     search_country      4
# 7          job level      2
# 8           job_type      3
# 9        job_summary   9927
# 10        job_skills  11209
# 11              Year      1
# 12             Month      1
# 13               Day      1
# 14        Month_Name      1
# 15  Number_of_Skills     84
# 16       Remote_Flag      3

# %%
df.memory_usage(deep=True)
# Out:
# Index                     132
# job_title              965772
# company                748571
# job_location           751421
# job_link              1683685
# first_seen             671656
# search_city            664280
# search_country         700501
# job level              668747
# job_type               626120
# job_summary         119407956
# job_skills            3977605
# Year                    91072
# Month                   91072
# Day                     91072
# Month_Name             648888
# Number_of_Skills        91072
# Remote_Flag             91072
# dtype: int64

# %% [markdown]
# Handle Missing Values

# %%
df.isnull().sum()
# Out:
# job_title           0
# company             0
# job_location        0
# job_link            0
# first_seen          0
# search_city         0
# search_country      0
# job level           0
# job_type            0
# job_summary         0
# job_skills          0
# Year                0
# Month               0
# Day                 0
# Month_Name          0
# Number_of_Skills    0
# Remote_Flag         0
# dtype: int64

# %%
df['job_skills'].fillna('Not Specified', inplace=True)
df['job_summary'].fillna('Not Available', inplace=True)
df.to_csv("Jobs.csv", index=False)
df.head(3)
# Out:
#                             job_title                        company  \
# 0           Data Analyst-SQL, Tableau              Zortech Solutions
# 1  Market Research & Insights Analyst  Indiana University Foundation
# 2         Business Systems Analyst `1                   Cook Medical
#
#         job_location                                           job_link  \
# 0  Mountain View, CA    https://www.linkedin.com/jobs/data-analyst-jobs
# 1    Bloomington, IN  https://www.linkedin.com/jobs/view/market-rese...
# 2    Bloomington, IN  https://www.linkedin.com/jobs/view/business-sy...
#
#    first_seen  search_city search_country   job level job_type  \
# 0  2023-12-20  Bloomington  United States   Associate   Onsite
# 1  2023-12-20  Bloomington  United States  Mid senior   Onsite
# 2  2023-12-20  Bloomington  United States  Mid senior   Onsite
#
#                                          job_summary  \
# 0                                      Not Available
# 1  Company Description\nAre you a high-performer ...
# 2  Overview\nThe Business Systems Analyst 1 perfo...
#
#                                           job_skills  Year  Month  Day  \
# 0                                      Not Specified  2023     12   20
# 1  Data analysis, Market research, Survey develop...  2023     12   20
# 2  Business Analysis, Technical Writing, Software...  2023     12   20
#
#   Month_Name  Number_of_Skills  Remote_Flag
# 0   December                 1            0
# 1   December                23            0
# 2   December                12            0

# %% [markdown]
# Check Duplicates Rows

# %%
duplicate_rows=df.duplicated().sum()
print(f"Number of Duplicated Rows : {duplicate_rows}")
# Out:
# Number of Duplicated Rows : 0

# %% [markdown]
# Feature Engineering

# %%
df.head(1)
df['first_seen']=pd.to_datetime(df['first_seen'])
df['Year']=df['first_seen'].dt.year
df['Month']=df['first_seen'].dt.month
df['Day']=df['first_seen'].dt.day
df['Month_Name']=df['first_seen'].dt.month_name()
df[['first_seen', 'Year', 'Month', 'Day','Month_Name']].head()
df.to_csv("Jobs.csv", index=False)

# %%
df.head(3)
# Out:
#                             job_title                        company  \
# 0           Data Analyst-SQL, Tableau              Zortech Solutions
# 1  Market Research & Insights Analyst  Indiana University Foundation
# 2         Business Systems Analyst `1                   Cook Medical
#
#         job_location                                           job_link  \
# 0  Mountain View, CA    https://www.linkedin.com/jobs/data-analyst-jobs
# 1    Bloomington, IN  https://www.linkedin.com/jobs/view/market-rese...
# 2    Bloomington, IN  https://www.linkedin.com/jobs/view/business-sy...
#
#   first_seen  search_city search_country   job level job_type  \
# 0 2023-12-20  Bloomington  United States   Associate   Onsite
# 1 2023-12-20  Bloomington  United States  Mid senior   Onsite
# 2 2023-12-20  Bloomington  United States  Mid senior   Onsite
#
#                                          job_summary  \
# 0                                      Not Available
# 1  Company Description\nAre you a high-performer ...
# 2  Overview\nThe Business Systems Analyst 1 perfo...
#
#                                           job_skills  Year  Month  Day  \
# 0                                      Not Specified  2023     12   20
# 1  Data analysis, Market research, Survey develop...  2023     12   20
# 2  Business Analysis, Technical Writing, Software...  2023     12   20
#
#   Month_Name  Number_of_Skills  Remote_Flag
# 0   December                 1            0
# 1   December                23            0
# 2   December                12            0

# %%
df['Number_of_Skills']=df['job_skills'].str.split(',').str.len()
df['Number_of_Skills'].head(10)
# Out:
# 0     1
# 1    23
# 2    12
# 3    36
# 4    27
# 5    16
# 6     1
# 7     1
# 8    14
# 9    14
# Name: Number_of_Skills, dtype: int64

# %%
df['Remote_Flag']=df['job_type'].map({'Onsite':0,'Remote':1,'Hybrid':2})
df['Remote_Flag'].head(5)
df.to_csv('Jobs.csv',index=False)

# %%
df.head(4)
# Out:
#                              job_title                        company  \
# 0            Data Analyst-SQL, Tableau              Zortech Solutions
# 1   Market Research & Insights Analyst  Indiana University Foundation
# 2          Business Systems Analyst `1                   Cook Medical
# 3  Senior VAT and Indirect Tax Analyst                           Epic
#
#         job_location                                           job_link  \
# 0  Mountain View, CA    https://www.linkedin.com/jobs/data-analyst-jobs
# 1    Bloomington, IN  https://www.linkedin.com/jobs/view/market-rese...
# 2    Bloomington, IN  https://www.linkedin.com/jobs/view/business-sy...
# 3    Bloomington, IN  https://www.linkedin.com/jobs/view/senior-vat-...
#
#   first_seen  search_city search_country   job level job_type  \
# 0 2023-12-20  Bloomington  United States   Associate   Onsite
# 1 2023-12-20  Bloomington  United States  Mid senior   Onsite
# 2 2023-12-20  Bloomington  United States  Mid senior   Onsite
# 3 2023-12-20  Bloomington  United States  Mid senior   Onsite
#
#                                          job_summary  \
# 0                                      Not Available
# 1  Company Description\nAre you a high-performer ...
# 2  Overview\nThe Business Systems Analyst 1 perfo...
# 3  We're looking for an experienced tax professio...
#
#                                           job_skills  Year  Month  Day  \
# 0                                      Not Specified  2023     12   20
# 1  Data analysis, Market research, Survey develop...  2023     12   20
# 2  Business Analysis, Technical Writing, Software...  2023     12   20
# 3  Accounting, Finance, VAT/GST tax regimes, US a...  2023     12   20
#
#   Month_Name  Number_of_Skills  Remote_Flag
# 0   December                 1            0
# 1   December                23            0
# 2   December                12            0
# 3   December                36            0

# %% [markdown]
# Job Market Overview

# %%
# Total Jobs
Total_No_Jobs=len(set(df['job_title']))
print(f'Total Number of Jobs are :{Total_No_Jobs}')
# Out:
# Total Number of Jobs are :6088

# %%
# Total Number of Job Posting
Total_No_Jobs = len(df)
print(f'Total Number of Job Postings are: {Total_No_Jobs}')
# Out:
# Total Number of Job Postings are: 11384

# %%
# Total Companies 
Total_Companies=df['company'].nunique()
print(f'Total Number of Companies are :{Total_Companies}')
# Out:
# Total Number of Companies are :4751

# %%
# Total Countries
Total_Countries=df['search_country'].nunique()
print(f'Total Number of Countires are :{Total_Countries}')
# Out:
# Total Number of Countires are :4

# %%
# Total Cities
Total_Cities=df['search_city'].nunique()
print(f'Total Number of Cities are :{Total_Cities}')
# Out:
# Total Number of Cities are :680

# %% [markdown]
# Job Title Analysis

# %%
# Top 20 most demanded job
df.columns
Top_20_Jobs = (
    df['job_title']
    .value_counts()
    .head(20)
    .reset_index()
)
Top_20_Jobs.columns = ['Job Title', 'Number of Job Postings']
Top_20_Jobs
# Out:
#                                             Job Title  Number of Job Postings
# 0                                    Business Analyst                     370
# 1                                        Data Analyst                     287
# 2                            Senior Financial Analyst                     249
# 3                                 Senior Data Analyst                     219
# 4                            Business Systems Analyst                     176
# 5                       Business Intelligence Analyst                     127
# 6                             Business System Analyst                      86
# 7                 Senior VAT and Indirect Tax Analyst                      78
# 8                            35F Intelligence Analyst                      77
# 9   Senior Associate, Senior Security Operations A...                      70
# 10  Lead Analyst Identity Governance and Administr...                      65
# 11                              Business Data Analyst                      65
# 12  Data Catalog and Lineage Central Governance An...                      58
# 13                         Technical Business Analyst                      56
# 14                            Senior Business Analyst                      52
# 15                                   Sr. Data Analyst                      52
# 16                                IT Business Analyst                      51
# 17                         US Tech - Business Analyst                      40
# 18                       US Tech Sr. Business Analyst                      38
# 19                             Financial Data Analyst                      36

# %%
sns.barplot(
    data=Top_20_Jobs,x='Number of Job Postings',y='Job Title',hue='Job Title',palette='crest',      
    dodge=False,
    saturation=0.9,       
    edgecolor='black',
    linewidth=1.5,
    width=0.7,                 
    legend=False
)
plt.title('Top 20 Most Demand Jobs')
plt.xlabel('Number of Job Postings')
plt.ylabel('Jobs')
# Out:
# Text(0, 0.5, 'Jobs')

# %%
# Least common job
Least_Jobs=df['job_title'].value_counts().tail(10).reset_index(name='Number of Postings')
Least_Jobs
# Out:
#                                            job_title  Number of Postings
# 0             Quality Assurance Analyst - Compliance                   1
# 1                  Senior Analyst (Investor Insight)                   1
# 2       Senior Actuarial Analyst - Programs - Remote                   1
# 3  IT Project Manager/ Business Analyst  Salesfor...                   1
# 4                          HCP PM / Business Analyst                   1
# 5  Business Analyst - Whippany, NJ ( Contract - o...                   1
# 6               ERP Business Analyst - Source to Pay                   1
# 7                           ERP Business Analyst-MTD                   1
# 8                   ERP Business Analyst - Reporting                   1
# 9                    Security Analyst/ Test Engineer                   1

# %%
sns.barplot(data=Least_Jobs,x='Number of Postings',y='job_title',hue='job_title',palette='Set2',
            edgecolor='black', 
            linewidth=1.5,
            width=0.7, )
plt.title('Least Job Postings')
plt.xlabel('Number of Job Postings')
plt.ylabel('Jobs')
# Out:
# Text(0, 0.5, 'Jobs')

# %%
data_analyst_jobs = df[df['job_title'] == 'Data Analyst']

Top_Companies = (
    data_analyst_jobs['company']
    .value_counts()
    .head(20)
    .reset_index(name='Number of Job Posting')
)
Top_Companies
# Out:
#                                              company  Number of Job Posting
# 0                                     Insight Global                     11
# 1                                            GradBay                      6
# 2                                       Apex Systems                      5
# 3                                Steneral Consulting                      5
# 4                                       Latitude Inc                      5
# 5                                 Motion Recruitment                      4
# 6                                     ASK Consulting                      4
# 7                                        Brooksource                      3
# 8                                             Stripe                      3
# 9                                    LanceSoft, Inc.                      3
# 10                                     Valera Health                      3
# 11                                       Accroid Inc                      3
# 12                                          Primient                      3
# 13                                     Tech Mahindra                      2
# 14                                    Adame Services                      2
# 15  Kelly Science, Engineering, Technology & Telecom                      2
# 16                                          ZoomInfo                      2
# 17                          Lorven Technologies Inc.                      2
# 18                                            OxBlue                      2
# 19                                       Cypress HCM                      2

# %%
# Average number of postings per company
avg_posting=df.groupby('company')['job_title'].count().reset_index(name='Number of Postings').sort_values(by='Number of Postings',ascending=False)
avg_posting.head(10)
# Out:
#                     company  Number of Postings
# 972           ClearanceJobs                 185
# 3846    Steneral Consulting                 169
# 3257                    PwC                 148
# 3445            Robert Half                  90
# 2255                KPMG US                  83
# 189                   Agoda                  80
# 1470                   Epic                  78
# 3843  Stellar Professionals                  72
# 4522        WSP in the U.S.                  65
# 1282                   Dice                  56

# %%
top_10=avg_posting.head(10)
sns.barplot(data=top_10,x='Number of Postings',y='company',hue='company',palette='viridis',edgecolor='black',linewidth=2)
plt.style.use('ggplot')
plt.xlim()
plt.ylim()
plt.title('Average Number of Postings per company')
plt.xlabel('Number of Posting')
plt.ylabel('Companies')
# Out:
# Text(0, 0.5, 'Companies')

# %%
companies_multiple_roles = (
    df.groupby("company")["job_title"]
      .nunique()
      .reset_index(name="Number of Job Roles")
      .query("`Number of Job Roles` > 1")
      .sort_values(by="Number of Job Roles", ascending=False)
)
companies_multiple_roles.head(10)
# Out:
#                                       company  Number of Job Roles
# 972                             ClearanceJobs                  154
# 3846                      Steneral Consulting                  151
# 1719                 Get It Recruit - Finance                   49
# 1282                                     Dice                   49
# 3445                              Robert Half                   45
# 3843                    Stellar Professionals                   45
# 2298                               Kforce Inc                   43
# 2121                           Intellectt Inc                   40
# 1722  Get It Recruit - Information Technology                   40
# 4681                        Zortech Solutions                   35
